# %% [markdown]
# YOOOOOOOOOOOOOOOOOOUUUUUUUUSSEF Missoum & WIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIILLIAM Zhang

# %% [markdown]
# Code needed for rendering of videos and gifs

# %%
from IPython.display import Image
from IPython.display import Video

# %% [markdown]
# #Intro

# %% [markdown]
# Simple harmonic motion (SHM) is a basic concept. One of the most common demonstrations of such a motion is with pendulum motion at small angles. Through the usage of Newtons equations, it is possible to predict the motion of a pendulum and see that it would become a SHM one at those small angles. However, such a motion is one of the most basic ones, as we only have string and mass that we attach to a pivot.
#
# We wanted to complexify this problem to get familiar with more complex numerical approximation model and to study aspects of a complex system. Hence, in this project we are trying to see if it is possible to create a program capable of simulating spring pendulum motion. With this model, aspects of the spring pendulum will be observed and studied : chaos and autoparametric resonance. To do so, we will get the equations of motion using Lagrangian mechanics, and we will use the Runge-Kutta method to solve the differential equations, as it is more precise than Euler’s methods.

# %% [markdown]
# #Model & Numerical Methods

# %% [markdown]
# Our model is a 2D spring pendulum system, where the ball and the pivot are directly attached to the spring. The spring is considered to be massless and non bending. The length of the spring at rest is given by $l_{0}$. A positive angle $\theta$ is defined in the counter clockwise direction from the middle line of the system. Friction is not considered in our system.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Image from https://www.researchgate.net/figure/Spring-pendulum-system_fig3_314133593

# %% [markdown]
# Such a system is way more complex than a simple pendulum system. Due to that, it is too complicated to get the equation of motion using Newton’s equations. Hence, we will use Lagrangian mechanics.  The main difference between Lagrangian mechanics from Newtonian mechanics is that with the Lagrangian, we use the energy of the system to get the equations of motion.
#
# To start, we must get the value of the Lagrangian which is: $L=T-V$, where $T$ is the total kinetic energy of the system which in this case will include both a radial translation component from the spring motion and a rotational one from the pendulum swings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Combining both the translation and rotational energy we obtain,
# \begin{align}
# T = K
# \end{align}
# \begin{align}
# K = \frac{1}{2}I\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2}
# \end{align}
# where $I$ is the moment of inertia of the ball and $r$ is the length of the extension of the spring at any moment. More specifically it is the distance between the $l_{0}$ and the center of mass of the ball as part of the spring is hooked to the center of the ball.
# \begin{align}
# \end{align}
# The moment of inertia of a ball from its center of mass is $\frac{2}{5}mR^{2}$. However, the ball is rotating from the pivot of the pendulum. We must therefore account the change in pivot with the parallex axis theorem. Doing so gives us the moment of inertia of
# \begin{align}
# I = \frac{2}{5}mR_{ball}^{2} + m(l_{0}+r)^{2}
# \end{align}
#
# Substituting the moment of inertia into the Kinetic energy equation, we obtain
# \begin{align}
# K = \frac{1}{2}(\frac{2}{5}mR_{ball}^{2} +  m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2}
# \end{align}
# \begin{align}
# K = (\frac{1}{5}mR_{ball}^{2} + \frac{1}{2} m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2}
# \end{align}

# %% [markdown]
# As for $V$ in the Lagrangian equation, it represents the potential energy of the system which includes both the gravitational energy and the spring potential energy. Putting both of these in an equation gives us
#
# \begin{align}
# V = -mg(l_{0}+r)\cos(\theta) + \frac{1}{2}kr^{2}
# \end{align}
#
# The negative sign is chosen here as we set the gravitational potential energy to be 0 at the pivot of the pendulum. $k$ here represents the spring constant.
#
# Putting both these $T$ and $V$ expressions into the Lagrangian, we get this following equation:
#
# \begin{align}
# L = T - V
# \end{align}
#
# \begin{align}
# L = (\frac{1}{5}mR_{ball}^{2} + \frac{1}{2} m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2} - (-mg(l_{0}+r)\cos(\theta) + \frac{1}{2}kr^{2})
# \end{align}
#
# \begin{align}
# L = (\frac{1}{5}mR_{ball}^{2} + \frac{1}{2} m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2} + mg(l_{0}+r)\cos(\theta) - \frac{1}{2}kr^{2}
# \end{align}

# %% [markdown]
# From Lagrangian mechanics, a system will always follow the motion of the smallest variation of action, $A$, where
#
# \begin{align}
# A=∫L \,dt
# \end{align}
#
# Using this fact,
# it is possible to derive Euler-Lagrange equation which are the equations of motion with the following:
# \begin{align}
# \frac{d}{dt} (\frac{∂L}{∂\dot{q}}) = \frac{∂L}{∂q}
# \end{align}
#
#
#
# where $q$ is the configuration space, which in our case is the polar coordinates $r$ and $\theta$. Then, by substituting the Lagrangian, in this equation, it is possible to get those two equations for $\ddot{{r}}$ and $\ddot{\theta}$.

# %% [markdown]
# For example, for $r$, we start off by taking $\frac{∂L}{∂\dot{r}}$, this gives us
# \begin{align}
# \frac{∂L}{∂\dot{r}} = \frac{∂}{∂\dot{r}} [(\frac{1}{5}mR_{ball}^{2} + \frac{1}{2} m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2} + mg(l_{0}+r)\cos(\theta) - \frac{1}{2}kr^{2}]
# \end{align}
#
# \begin{align}
# \frac{∂L}{∂\dot{r}} =  0 + (m\dot{r}) + 0 -0
# \end{align}
#
# \begin{align}
# \frac{∂L}{∂\dot{r}} =   (m\dot{r})
# \end{align}
#
#
# \begin{align}
# \end{align}
#
# Notice here that $r$ and $\dot{r}$ are treated as independant of one another. Then, we take the time derivative of this expression giving us
#
# \begin{align}
# \frac{d}{dt}\frac{∂L}{∂\dot{r}} = \frac{d}{dt}  (m\dot{r})
# \end{align}
#
# \begin{align}
# \frac{d}{dt}\frac{∂L}{∂\dot{r}} =  (m\ddot{r})
# \end{align}
#
# \begin{align}
# \end{align}
# On the other side of the equation, we have
#
# \begin{align}
# \frac{∂L}{∂r} = \frac{∂}{∂{r}} [(\frac{1}{5}mR_{ball}^{2} + \frac{1}{2} m(l_{0}+r)^{2})\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2} + mg(l_{0}+r)\cos(\theta) - \frac{1}{2}kr^{2}]
# \end{align}
#
# \begin{align}
# \frac{∂L}{∂r} = \frac{∂}{∂{r}}[ (\frac{1}{5}mR_{ball}^{2})\dot{\theta}^{2}  + \frac{1}{2} m(l_{0}+r)^{2}\dot{\theta}^{2} + \frac{1}{2}m\dot{r}^{2} + mg(l_{0}+r)\cos(\theta) - \frac{1}{2}kr^{2}]
# \end{align}
#
# \begin{align}
# \frac{∂L}{∂r} = 0 +  m(l_{0}+r)\dot{\theta}^{2} + mg\cos(\theta) - kr
# \end{align}
#
#
# \begin{align}
# \end{align}
#
# Putting both equations together we get
#
#
# \begin{align}
# m\ddot{r} = m(l_{0}+r)\dot{\theta}^{2} + mg\cos(\theta) - kr
# \end{align}
# \begin{align}
# \ddot{r} = (l_{0}+r)\dot{\theta}^{2} + g\cos(\theta) - \frac{k}{m}r \tag 1
# \end{align}

# %% [markdown]
# Following a similar process but with the coordinate $\theta$, we obtain the angular acceleration,
#
# \begin{align}
# \ddot{\theta} = \frac{(l_{0}+r)(-g\sin(\theta) - 2\dot{\theta}\dot{r})}{\frac{2R^{2}}{5}+(l_{0}+r)^{2}} \tag 2
# \end{align}

# %% [markdown]
# To accurately compute the equations of motion, a precise numerical integrator was needed. To do so, the Runge-Kutta algorithm of order 4 was implemented in this model. Essentially, the Runge-Kutta method can solve a system of differential equations with derivative time steps DT. With the derivative formula, the order 4 variant computes the derivative at 4 spots and uses a weighted average from them to obtain an average slope. The spots where the derivative is calculated can be shown with this diagram:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Diagram from https://tpaschalis.me/rk4-explained/

# %% [markdown]
#  The first slope value is calculated with our initial coordinates using the derivative. This will be $k_{1}$. With this slope value, we find a new y value at a half of DT. At this new point, we calculated $k_{2}$, the slope at this new point. This slope value $k_{2}$ is then used in similar fashion to find a new point starting from our initial coordinates. The derivative calculated at that point is $k_{3}$.  The last point is obtained with a full step DT of the derivative $k_{3}$ from our initial coordinates. The derivative at that point is $k_{4}$. Finally, all derivatives are weighted in this fashion to obtain a slope that will best approximate the next point of the integrated function:
#
# \begin{align}
# k_{optimal} = \frac{1}{6}(k_{1} + 2k_{2} + 2k_{3}+k_{4}) \tag 3
# \end{align}
#
# When the function is multivariable, each variable has its own Eq(3).
#
# \begin{align}
# \end{align}
# Runge-Kutta of order 4 (RK4) is chosen instead of Euler’s method as the latter is not accurate enough for our model for long simulations. With each step, inaccuracy builds up no matter what integrator but Euler’s method falls apart faster as the pendulum starts flying towards infinity.

# %% [markdown]
# Using RK4 with Eq(1) and Eq(2), we made functions to calculate the evolution of variables describing the system. This was then combined with matplotlib to produce graphs that would allow us to study the behaviour of the system.

# %% [markdown]
# #Testing

# %% [markdown]
# To test, if our code works, we verified both extreme cases of the spring pendulum: the pendulum and the spring. If our model is accurate then in the case where the spring is really rigid, that is it has a very large $k$, it should replicate a pendulum motion, which our program does confirming that it works for this test as we simulate motion with a $k$ of $4000 \frac{N}{m}$.

# %%
Image(url='https://raw.githubusercontent.com/schnozerman/Spring-pendulum/main/Spring_pendulum_penduluming.gif')
# Out:
# <img src="https://raw.githubusercontent.com/schnozerman/Spring-pendulum/main/Spring_pendulum_penduluming.gif"/>

# %% [markdown]
# For the other extreme, a SHM motion of a spring going only up and downs should also be possible if our spring pendulum starts at $\theta$ and a $\dot{\theta}$ of $0$. If we stretch the spring to any length, it should go back and forth.

# %%
Image(url='https://raw.githubusercontent.com/schnozerman/Spring-pendulum/main/SHM_spring_pendulum.gif')
# Out:
# <img src="https://raw.githubusercontent.com/schnozerman/Spring-pendulum/main/SHM_spring_pendulum.gif"/>

# %% [markdown]
# Finally, we compared our system with an actual real spring pendulum system where $l_{0} = 8.1 cm,\ k = 3.0\frac{N}{m}, \dot{\theta} = 0 \frac{rad}{s},\ r = \frac{mg}{k},\ \dot{r} = 0 \frac{m}{s}$ and $\theta \approx 30°$:

# %%
Video('https://github.com/schnozerman/Spring-pendulum/raw/main/Real%20world%20model%20+%20simulation%20comparison/20240525_144558.mp4')
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/Real%20world%20model%20+%20simulation%20comparison/20240525_144558.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video('https://github.com/schnozerman/Spring-pendulum/raw/main/Real%20world%20model%20+%20simulation%20comparison/world%20model%20comparison.mp4')
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/Real%20world%20model%20+%20simulation%20comparison/world%20model%20comparison.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# If we look only at the shadow of the ball, as it is the projection of the 3D motion of the ball on a 2D plane, we can see that qualitatively our simulation represents some properties of the physical motion. The most interesting one is how, at some point the spring compresses on the left, other times it is quite ambiguous, and other times the spring compresses clearly on the right. Our simulation could predict this transition even the in-between parts that we more ambiguous. Indeed, the real world model has 4 clear bounces on the left side 4 times followed by 2 in between bounces and one right side bounce. Our model predicts the similar case. The longer the comparison goes, the less accurate our model becomes as friction starts impacting the real word model while not being present in our simulation.
#
# Hence, at the very least, our program can predict the motion of a spring pendulum system in a qualitative manner.

# %% [markdown]
# #Results and discussion

# %% [markdown]
# With this model in hand, many interesting properties of the spring pendulum can be simulated.
#
# Firstly, chaos can be examined with the simulation. A spring pendulum system can be chaotic, that is the system is very sensitive to the initial conditions. Having 6 degrees of freedom, we looked at the impact of various combinations of these variables to observe the change in motion of the spring pendulum. However, it is to be noted that we do not choose extreme cases like those in the testing section, as those are not chaotic; they are predictable.

# %% [markdown]
# To study chaos, two initial pendulums were set up with $l_0 = 0.081 m,\ r_{0} = \frac{mg}{k},\ \dot{r} = 0,\ \dot{\theta} = 0,\ m = 0.09 kg, \ k=3\frac{N}{m}$. The first pendulum, the blue one, had an initial $\theta$ of $\frac{\pi}{6}$ while the other pendulum's, the green one, initial $\theta$ was $0.55$ rad or around $0.03$ rad (or 1.7°) of difference. Letting the pendulums swing, we can see changes start to appear in their motion.

# %%
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/CHAOS.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# (sorry for lack of labeling, we may be out of time as that render takes hours)

# %% [markdown]
# These pendulums seem to be in sync most of the way and differences gradually add up. A better way to study these systems to see possible patterns or semi-periods, amount of time where it seems the system almost comes back to its original state, is with a phase diagram. A phase diagram plots $\theta$ against $\dot{\theta}$ and allows us to see the evolution of the state of our system.

# %% [markdown]
# If we show the entirety of the phase space over the 194 seconds simulated for our pendulums, we obtain this following graph.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# While it is very messy, we can still observe interesting details about our system. Indeed, the different pendulums occupy different corners of the phase space. The green one occupies more presence in the top right and bottom left corners while the blue one is in the other corners. This helps us see how different initial conditions can change which states the spring pendulum are capable of ending up occupying.

# %% [markdown]
# Another initial condition impact we observed was the the extension length of the spring. Given the same initial conditions as with the blue pendulum, various phase spaces were made. Initially, we compared two extremes of spring extensions, namely an inital length extension of 0, and one of 3 times $l_{0}$. From these we obtain the following phase spaces that described the motion for 20 seconds:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Seeing as the phase space immensely changed due to only one variable of the intial condition, we decided to observe the evolution of the phase space according to slight nudges in the initial extension. For every extension lengths that were multiples of the rest length, a phase space lasting 20 seconds was created.

# %%
Video('https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Evolution%20of%20phase%20space%20.mp4')
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Evolution%20of%20phase%20space%20.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# (our mistake for forgetting to put the $l_{0}$ next to the r = )

# %% [markdown]
# We can note that no matter the extension lengths the bounds of the plot never seem to change much. The system seems to always stay within certain ranges of $\dot{\theta}$. Interestingly, the phase space seems to align for certain extension lengths. This shows the relatively short semi-period of these trajectories. A semi-period is the amount of time taken before the pendulum gets very close to having the same initial conditions as the start. Due to chaotic natures, there is never a perfect period where the spring gets back perfectly to its initial conditions. As $r_{0}$ increases, the center part of the phase space that is not covered within the first 20 seconds increases. This makes sense as a bigger extension would lead to a greater starting angular speed. Also, while some motions may look periodical like when $r_{0} = 1.69\ l_{0}$ , they are not. We can see this if the total time of the simulation increases.The phase space of the system when $r_{0} = 1.69\ l_{0}$ over $2000$ seconds looks like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Plotting the physical trajectory of all these extension lengths initial conditions we obtain

# %%
Video('https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Evolution%20of%20trajectories.mp4')
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Evolution%20of%20trajectories.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Nearly symmetrical patterns appear in the motion of the spring pendulum, however those trajectories seem to become larger in width as the extension length increases, and again we see the chaos effect on the graph, as there is a significant changes in the motion of the pendulum, as we change the value of r initial.

# %% [markdown]
# Secondly, the auto-parametric resonance of the spring pendulum system can also be studied. Resonance is the concept of giving a system a driving force that matches the system's natural frequency to give it more energy. In the case of the spring pendulum, we can view the overall system as two smaller systems: the spring and the pendulum. Auto-parametric resonance occurs when one of the systems gives energy to the other and vice-versa. Qualitatively, this would be like our system initially acting only as a spring and slowly transitioning to a pendulum motion before going back to a spring motion.
#
# The specifics of auto-parametric resonance are complex. It involves matching the frequencies of the pendulum to that of the spring so that they can transfer energy between the two. Simply put, from  Duka and Duka's paper "On the elastic pendulum, parametric resonance and 'pumping' swings (2018), the system’s initial conditions have to be carefully tuned. The length of the pendulum has to respect this equation:
# \begin{align}
# l_{0} = \frac{2.23mg}{k}
# \end{align}
#
# Additionnally, the initial extension of the spring must be
# \begin{align}
# r_{0} = \frac{0.0748\ l_{0}}{0.0942}
# \end{align}

# %% [markdown]
# Taking the mass and $k$ of our blue pendulum, we obtain an $l_{0}$ of 0.656$m$ and $r_{0}$ of 0.521$m$. We start the motion with $\theta = 0$ and an tiny bit of angular speed so that it can be amplified. Autoparametric resonance was not seen when $\dot{\theta}$ was equal to $0$ as only a SHM spring motion was seen in the simulation. So, our program managed to showcase auto-prametric resonance:

# %%
Video('https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Autoparametric_resonance.mp4')
# Out:
# <video src="https://github.com/schnozerman/Spring-pendulum/raw/main/simulations/Autoparametric_resonance.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# This increase in motion of the pendulum can also be seen in the phase space.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hence, we have managed to create a program that is at the very least capable of simulating some of the properties of spring pendulum motion. However, we had to do some assumptions in our model. First, we have assumed energy was conserved meaning that there was no friction in our system. Secondly, we assumed that the ball could not rotate around its center of mass, which is false as we saw it rotate when we did the real pendulum spring motion. Then, we assumed for the spring that it was a perfect hooks law spring, and that it could not bend which isn't the case in the real world.
#
# Finally, a limitation would be the innacuracy of our model. In other words, to test the validity of the simulation, we used conservation of energy. If our model is perfectly accurate, the energy at the start of the simulation should be the same as the energy throughout the whole simulation. However, as errors are added from the inaccuracy of every step calculation, the energy of the system is altered. To analyze the mistakes of our system, a plot of the total energy and the time of our simulation was created. For example, here is the energy time plot of the autoparametric resonant spring pendulum we just simulated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hence, we see that conservation of energy is not respect; the total energy changes. However, instead of rapidly augmenting towards infinity as errors add up per time step, the energy follows an up and down pattern. This shows how our model is still somewhat accurate within a bound of error. Interestingly, this limitation of our model reflects the semi-periods of motion of our pendulum. The period of the huge dips of what looks like beat frequencies matches the semi-period of our auto-parametric spring pendulum. Moreover, the pattern stays constant even at larger times. This beat pattern is not unique to the resonant spring pendulums. For example, here is one with a pendulum with $l_0 = 0.081 m,\ r_{0} = \frac{3mg}{k},\ \theta = \frac{\pi}{6},\ \dot{r} = 0,\ \dot{\theta} = 0,\ m = 0.09 kg, \ k=3\frac{N}{m}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Some interesting things that could be done in future studies first would be to improve our program by adding friction, and spring bending in our program to see how it would affect the pendulum spring motion. Not only that, but the next steps of our study would be to calculate the motion of the pendulum in 3D to try and see if, for different third components, it would be possible to find 2 different combinations that would project the same 2D motions like if the motion of their shadows would be the same. Furthermore, we could study the impact of other initial conditions on the trajectories of the spring pendulum. Another interesting one would be to analyze our faulty energy time plot to find exactly what the oscillating motion of our innaccuracies in the energy conservation represents.

# %% [markdown]
# #Conclusion

# %% [markdown]
# In conclusion, we have created a program capable of predicting, at least, qualitatively, the motion of spring pendulum system, and through this program, we managed to simulate auto-parametric resonance, but also the chaos effect. In short, yes, it is possible to create a program capable of predicting spring pendulum motion in a qualitative way at the very least.

# %% [markdown]
# # Bibliography
#
# Auto-parametric resonance paper :
# source of paper: https://www.researchgate.net/publication/328976782_On_the_elastic_pendulum_parametric_resonance_and_pumpingswings
#
# Spring pendulum equations:
# https://scholar.harvard.edu/files/david-morin/files/cmchap6.pdf

# %% [markdown]
# #Code

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
#Defining constants
g = 9.81 # in N/kg
k = 3 #N/m
m = 0.09  #No mass spring and mass ball in Kg
l0 = 0.081 # In m
w = math.sqrt(k/m) #
theta_0 = math.pi/6 # In radians
v_theta_0 = 0.00000000 # Initial angular speed in rad/s
vr_0 = 0 #Initial radial speed in m/s
r_0 = m*g/k  # Initial stretch in m
DT = 0.001 # in seconds
T_MAX = 20.0 # Max time of the simulation in seconds
STEPS = int(T_MAX/DT) # Number of steps in the simulation
R = 0.05 # in m: radius of the ball

# %%
def ang_acc(r, v_r, theta, v_theta):
  '''To calculate angular acceleration'''
  if theta > math.pi:
    theta = theta - 2*math.pi
  elif theta < -math.pi:
    theta = theta + 2*math.pi

  return ((l0 +r)*(-g * math.sin(theta) - 2 * v_r * v_theta ) / ((2/5)*R**2 + (l0 + r)**2))

def radial_acc(r, theta, v_theta):
  '''To calculate radial acceleration'''
  if theta > math.pi:
    theta = theta - 2*math.pi
  elif theta < -math.pi:
    theta = theta + 2*math.pi

  return ( (l0 +r)*v_theta**2 + g*math.cos((theta)) - k*r/m)

# %%
# Energy quantities code
def T(v_r, r, v_theta, mass):
  return 0.5*mass*( ((2/5)*R**2+(l0+r)**2) * (v_theta**2) + v_r**2  )

def V(r, theta):
  return -m*g*(l0+r)*math.cos(theta) + 0.5*k*r**2

# %% [markdown]
# Runge-Kutta Method

# %%
def trajectory_rk(length_eq = l0,  r_0 = r_0 ,v_r_0 = vr_0, theta_0 = theta_0, v_theta_0 = v_theta_0):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''


  # Setup where first element of lists based on initial conditions
  t = [0]
  r = [r_0]
  v_r = [v_r_0]
  theta = [theta_0]
  v_theta = [v_theta_0]
  a_r = []
  a_theta = []
  x = [math.sin(theta_0) * (l0+r_0)]
  y = [-math.cos(theta_0) * (l0+r_0)]
  energy = [T(v_r[-1], r[-1], v_theta[-1], m,) - V(r[-1], theta[-1])]



  # Main Loop
  for i in range(STEPS):
    t.append(t[i]+DT)
    """Runge-Kutta methode on all the 4 variables involve in the motion"""
    k0 = DT * v_theta[-1] # theta change
    g0 = DT * v_r[-1] #radius or more specifically lenght of spring extension or compression cjamge
    l_0 = DT * ang_acc(r[-1], v_r[-1], theta[-1], v_theta[-1]) #angular velocity change
    j0 = DT * radial_acc(r[-1], theta[-1], v_theta[-1]) # radial velocity change


    k1 = DT * (v_theta[-1] + l_0/2)
    g1 = DT *(v_r[-1] + j0/2)
    l1 = DT * (ang_acc(r[-1] + g0/2, v_r[-1] + j0/2, theta[-1] + k0/2, v_theta[-1] + l_0/2))
    j1 = DT * (radial_acc(r[-1] + g0/2, theta[-1] + k0/2, v_theta[-1] + l_0/2))

    k2 = DT * (v_theta[-1] + l1/2)
    g2 = DT *(v_r[-1] + j1/2)
    l2 =  DT * (ang_acc(r[-1] + g1/2, v_r[-1] + j1/2, theta[-1] + k1/2, v_theta[-1] + l1/2))
    j2 = DT * (radial_acc(r[-1] + g1/2, theta[-1] + k1/2, v_theta[-1] + l1/2))

    k3 = DT * (v_theta[-1] + l2)
    g3 = DT *(v_r[-1] + j2)
    l3 = DT * (ang_acc(r[-1] + g2, v_r[-1] + j2, theta[-1] + k2, v_theta[-1] + l2))
    j3 = DT * (radial_acc(r[-1] + g2, theta[-1] + k2, v_theta[-1] + l2))

    r.append( r[-1] + (g0 + 2*g1 + 2*g2 + g3)/6 )

    #conditions to keep theta within -pi to pi as any angle outside this range can be expressed by values within the range
    if (theta[-1] + (k0 + 2*k1 + 2*k2 +k3)/6) > math.pi:
      theta.append( theta[-1] + (k0 + 2*k1 + 2*k2 +k3)/6  - 2*math.pi)

    elif (theta[-1] + (k0 + 2*k1 + 2*k2 +k3)/6) < -math.pi:
      theta.append( theta[-1] + (k0 + 2*k1 + 2*k2 +k3)/6  + 2*math.pi)

    else:
      theta.append( theta[-1] + (k0 + 2*k1 + 2*k2 +k3)/6  )


    energy.append( T(v_r[-1], r[-1], v_theta[-1], m,) - V(r[-1], theta[-1]) )

    v_theta.append(v_theta[-1] + (l_0 + 2*l1 + 2*l2 + l3)/6)
    v_r.append( v_r[-1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

    x.append(math.sin(theta[-1]) * (l0 + r[-1]) )
    y.append(-math.cos(theta[-1]) * (l0 + r[-1]))


  # new_x = []
  # new_y = []
  # for i in range(len(x)):
  #   if i % 10 == 0:
  #     new_x.append(x[i])
  #     new_y.append(y[i])
  final_energy = T(v_r[-1], r[-1], v_theta[-1], m,) - V(r[-1], theta[-1])
  print(final_energy)


  return x, y, theta, v_theta, r, v_r, energy, t

# %% [markdown]
# https://math.stackexchange.com/questions/721076/help-with-using-the-runge-kutta-4th-order-method-on-a-system-of-2-first-order-od

# %%
# Phase space diagram
x, y, theta, theta_dot, r, r_dot, energy, t = trajectory_rk()



#Make a masked array with jump points masked, manually uncomment this section when a phase space is crosses the angle boundaries

# abs_d_data_theta = np.abs(np.diff(theta))
# mask_theta = np.hstack([ abs_d_data_theta >= abs_d_data_theta.mean()+3*abs_d_data_theta.std(), [False]])
# masked_data_theta = np.ma.MaskedArray(theta, mask_theta)



plt.plot(theta, theta_dot)
plt.ylabel(r'$\dot{\theta}$')
plt.xlabel(r'$\theta$')
plt.title('Phase space of spring pendulum')
plt.grid()
plt.show()
# Out:
# 0.20321539596478677

# %%
plt.figure(figsize=(30, 6))
plt.title('Energy time plot of spring pendulum')
plt.ylabel('Energy (J)')
plt.xlabel('Time (s)')
plt.plot(t, energy)

# %%
# Phase space diagram in x and y coordinates


plt.plot(x, y)
plt.ylabel("y")
plt.xlabel("x")
plt.grid()
plt.show()

# %% [markdown]
# https://www.researchgate.net/publication/328976782_On_the_elastic_pendulum_parametric_resonance_and_pumpingswings
# Parametric resonance source

# %%
#code to make the animation of pendulum

#Defining values
g = 9.81 # in N/kg
k = 3 #N/m
m = 0.09  #No mass spring and mass ball in Kg
l0 = 0.081 # In m
w = math.sqrt(k/m) #
theta_0 = math.pi/6 # In radians
v_theta_0 = 0.00000000 # Initial angular speed in rad/s
vr_0 = 0 #Initial radial speed in m/s
r_0 = m*g/k  # Initial stretch in m

DT = 0.01
interval = 10/DT
T_MAX = 20

# Creation of arrays
state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
t = np.arange(0, T_MAX, DT)
state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial
l0_array = np.repeat(l0, len(t))
print(l0_array.ndim)

#Trajectory calculation array version
def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]

# Calculation of all trajectories
for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])

# Creating x and y positions of our trajectory from r and theta
x = (l0_array + state_pend[:,0])*np.sin(state_pend[:, 2])
y = -(l0_array + state_pend[:,0])*np.cos(state_pend[:, 2])

# Making the figure for plot
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(autoscale_on=False, ylim=(-0.7, 0.05), xlim=(-0.6, 0.6))
ax.set_title('Trajectory of spring pendulum')
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
#ax.set_aspect('equal')
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
trace, = ax.plot([], [], lw=1, ms=2, color='blue')
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# Animation function
def animate(i):
  thisx = [0, x[i]]
  thisy = [0, y[i]]

  history_x = x[:i]
  history_y = y[:i]

  line.set_data(thisx, thisy)
  #trace.set_data(history_x, history_y) # comment out the trace, because i dont want to see it but keep it as it can be useful
  time_text.set_text(time_template % (i*DT))
  return line, trace, time_text


frames = len(t)/T_MAX
ani_path = '/content/sample_data/animation.mp4'

# Animation
ani = animation.FuncAnimation(
    fig, animate, len(state_pend), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)
# Out:
# 1

# %% [markdown]
# Animation code for double pendulum

# %%
#Defining constants
g = 9.81 # in N/kg
k = 3 #N/m
m = 0.09  #No mass spring and mass in Kg
l0 = 0.081 # In m

theta_0 = math.pi/6 # Initial angle for pendulum 1 in radians
v_theta_0 = 0 # Initial angular speed for pendulum 1
vr_0 = 0  # Initial speed radial in m/s for pendulum 1
r_0 = m*g/k  # Initial stretch for pendulum 1

theta_0_2 = 0.55 # Initial angle for pendulum 2 In radians
v_theta_0_2 = 0 # Initial angular speed for second pendulum
vr_0_2 = 0  # Initial speed radial in m/s for second pendulum
r_0_2 = m*g/k  # Initial stretch for second pendulum

# Creation of arrays
state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
state_initial_2 = np.array([r_0_2, vr_0_2, theta_0_2, v_theta_0_2])
DT = 0.01
interval = 10/DT
T_MAX = 195

t = np.arange(0, T_MAX, DT)
state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial

state_pend2 = np.empty((len(t), 4))
state_pend2[0] = state_initial_2


l0_array = np.repeat(l0, len(t))
l0_array2 = np.repeat(l0, len(t))

#Function for trajectory calculation, this time in array form
def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]


for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])
  state_pend2[i] = trajectory_rk_numpy(state_pend2[i-1])

# Converting r and theta into x and y for both pendulums
x = (l0_array + state_pend[:,0])*np.sin(state_pend[:, 2])
y = -(l0_array + state_pend[:,0])*np.cos(state_pend[:, 2])

x2 = (l0_array2 + state_pend2[:,0])*np.sin(state_pend2[:, 2])
y2 = -(l0_array2 + state_pend2[:,0])*np.cos(state_pend2[:, 2])

# Creating figure for plot
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(autoscale_on=False, ylim=(-1, 0.05), xlim=(-0.6, 0.6))
ax.set_title('Trajectory of spring pendulum')
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
#ax.set_aspect('equal')
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
trace, = ax.plot([], [], '.-', lw=1, ms=2)
line2, = ax.plot([], [], 'o-', lw=2)
# trace2, = ax.plot([], [], '.-', lw=1, ms=2)

time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# Animation function
def animate(i):
  thisx = [0, x[i]]
  thisy = [0, y[i]]

  thisx2 = [0, x2[i]]
  thisy2 = [0, y2[i]]

  line.set_data(thisx, thisy)
  line2.set_data(thisx2, thisy2)
  time_text.set_text(time_template % (i*DT))
  return line, trace, time_text


frames = len(t)/T_MAX
ani_path = '/content/sample_data/animation.mp4'

#Animation
ani = animation.FuncAnimation(
    fig, animate, len(state_pend), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)
# Out:
# [1.000e+00 7.932e-01 0.000e+00 0.000e+00 1.000e-05]

# %% [markdown]
# Code for the phase space of both pendulums, it was an animation but we decided to just take the last frame

# %%
#Defining constants
g = 9.81 # in N/kg
k = 3 #N/m
m = 0.09  #No mass spring and mass in Kg
l0 = 0.081 # In m

theta_0 = math.pi/6 # Initial angle for pendulum 1 in radians
v_theta_0 = 0 # Initial angular speed for pendulum 1
vr_0 = 0  # Initial speed radial in m/s for pendulum 1
r_0 = m*g/k  # Initial stretch for pendulum 1

theta_0_2 = 0.55 # Initial angle for pendulum 2 In radians
v_theta_0_2 = 0 # Initial angular speed for second pendulum
vr_0_2 = 0  # Initial speed radial in m/s for second pendulum
r_0_2 = m*g/k  # Initial stretch for second pendulum

# Creation of arrays
state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
state_initial_2 = np.array([r_0_2, vr_0_2, theta_0_2, v_theta_0_2])
DT = 0.01
interval = 10/DT
T_MAX = 195

t = np.arange(0, T_MAX, DT)
state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial

state_pend2 = np.empty((len(t), 4))
state_pend2[0] = state_initial_2


l0_array = np.repeat(l0, len(t))
l0_array2 = np.repeat(l0, len(t))

#Function for trajectory calculation, this time in array form
def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]


for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])
  state_pend2[i] = trajectory_rk_numpy(state_pend2[i-1])

#Arrays of theta and theta dot of both pendulums
theta_array = (state_pend[:, 2])
theta_dot_array = (state_pend[:, 3])

theta_array2 = (state_pend2[:, 2])
theta_dot_array2 =(state_pend2[:, 3])

# Creating figure for plot
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(autoscale_on=False, ylim=(-math.pi, math.pi), xlim=(-0.6, 0.6))
ax.set_title('Trajectory of spring pendulum')
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
#ax.set_aspect('equal')
ax.grid()

trace, = ax.plot([], [],  lw=1, ms=2, color='blue')
trace2, = ax.plot([], [],  lw=1, ms=2, color='green')

time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# Animation function
def animate(i):
  history_x = theta_array[:i]
  history_y = theta_dot_array2[:i]

  history_x2 = theta_array2[:i]
  history_y2 = theta_dot_array[:i]

  trace.set_data(history_x, history_y)
  trace2.set_data(history_x2, history_y2)
  time_text.set_text(time_template % (i*DT))
  return trace, trace2, time_text


frames = len(t)/T_MAX
ani_path = '/content/sample_data/animation.mp4'

#Animation
ani = animation.FuncAnimation(
    fig, animate, len(state_pend), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     232         try:
# --> 233             yield self
#     234         finally:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1102                     # TODO: See if turning off blit is really necessary
# -> 1103                     anim._draw_next_frame(d, blit=False)
#    1104                     if progress_callback is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1138         self._draw_frame(framedata)
# -> 1139         self._post_draw(framedata, blit)
#    1140
#
# ...

# %% [markdown]
# Code for the different phase spaces depending on r_0

# %%
DT = 0.001
interval = 10/DT
T_MAX = 20


# Creation of arrays
state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
state_initial_2 = np.array([r_0_2, vr_0_2, theta_0_2, v_theta_0_2])
t = np.arange(0, T_MAX, DT)
list_length = np.arange(0, 3*l0, 0.01*l0) # different lengths in m array
interval = 10/len(list_length)

state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial

state_pend2 = np.empty((len(t), 4))
state_pend2[0] = state_initial_2


l0_array = np.repeat(l0, len(t))
l0_array2 = np.repeat(l0, len(t))

# Trajectory calculation with arrays
def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]


for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])
  state_pend2[i] = trajectory_rk_numpy(state_pend2[i-1])

theta_array = (state_pend[:, 2])
theta_dot_array = (state_pend[:, 3])

theta_array2 = (state_pend2[:, 2])
theta_dot_array2 =(state_pend2[:, 3])

# Creating figure for plot
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(autoscale_on=False, ylim=(-4.2, 4.2), xlim=(-1.6, 1.6))
ax.set_title('Phase space of spring pendulum')
ax.set_xlabel(r'$\theta$')
ax.set_ylabel(r'$\dot{\theta}$')
#ax.set_aspect('equal')
ax.grid()

point, = ax.plot([], [], 'o-', lw=2, color='blue')
trace, = ax.plot([], [],  lw=1, ms=1)
point2, = ax.plot([], [], 'o-', lw=2, color='green')
trace2, = ax.plot([], [], lw=1, ms=2, color='green')

time_template = 'time = %.1fs'
plot_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# Animation function
def animate(i):
  state_initial = np.array([list_length[i], vr_0, theta_0, v_theta_0])
  state_pend = np.empty((len(t), 4))
  state_pend[0] = state_initial

  for j in range(1, len(t)):
    state_pend[j] = trajectory_rk_numpy(state_pend[j-1])

  theta_array = (state_pend[:, 2])
  theta_dot_array = (state_pend[:, 3])

  trace.set_data(theta_array, theta_dot_array)

  plot_text.set_text(f' r = {round(list_length[i]/l0, 2)} l_0')

  return trace,


frames = 3
ani_path = '/content/sample_data/animation.mp4'
# Animation
ani = animation.FuncAnimation(
    fig, animate, len(list_length), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)

# %% [markdown]
# Code for the animation of the different trajectories depending on r_0

# %%
#Defining constants
g = 9.81 # In N/kg
k = 3 # In N/m
m = 0.09  #No mass spring
l0 = 0.081 # Rest length in m
theta_0 = math.pi/6 # In radians
v_theta_0 = 0.00000000 # Initial angular speed rad/s
vr_0 = 0 # Initial radial speed m/s
DT = 0.0001 # In seconds
T_MAX = 20.0 # Max time of the simulation
STEPS = int(T_MAX/DT) # Number of steps in the simulation
R = 0.05 # In m

# Creation of arrays
state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
state_initial_2 = np.array([r_0_2, vr_0_2, theta_0_2, v_theta_0_2])
DT = 0.01
interval = 10/DT
T_MAX = 20


t = np.arange(0, T_MAX, DT)
list_length = np.arange(0, 3*l0, 0.01*l0) #array of initial streches in m
interval = 10/len(list_length)
state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial

state_pend2 = np.empty((len(t), 4))
state_pend2[0] = state_initial_2


l0_array = np.repeat(l0, len(t))
l0_array2 = np.repeat(l0, len(t))

# Trajectory calculation with arrays
def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]


for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])
  state_pend2[i] = trajectory_rk_numpy(state_pend2[i-1])

theta_array = (state_pend[:, 2])
theta_dot_array = (state_pend[:, 3])

theta_array2 = (state_pend2[:, 2])
theta_dot_array2 =(state_pend2[:, 3])

# Creating figure for plot
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(autoscale_on=False, ylim=(-0.7, -0), xlim=(-0.17, 0.17))
ax.set_title('Trajectory of spring pendulum')
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
#ax.set_aspect('equal')
ax.grid()

point, = ax.plot([], [], 'o-', lw=2, color='blue')
trace, = ax.plot([], [],  lw=1, ms=1)
point2, = ax.plot([], [], 'o-', lw=2, color='green')
trace2, = ax.plot([], [], lw=1, ms=2, color='green')

time_template = 'time = %.1fs'
plot_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)


# Animation function
def animate(i):
  state_initial = np.array([list_length[i], vr_0, theta_0, v_theta_0])
  state_pend = np.empty((len(t), 4))
  state_pend[0] = state_initial

  for j in range(1, len(t)):
    state_pend[j] = trajectory_rk_numpy(state_pend[j-1])

  x = (l0_array + state_pend[:,0])*np.sin(state_pend[:, 2])
  y = -(l0_array + state_pend[:,0])*np.cos(state_pend[:, 2])

  trace.set_data(x, y)

  plot_text.set_text(f' r = {round(list_length[i]/l0, 2)} l_0')

  return trace,


frames = 3
ani_path = '/content/sample_data/animation.mp4'

# Animation
ani = animation.FuncAnimation(
    fig, animate, len(list_length), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)

# %% [markdown]
# Code for the phase spaces of both pendulums

# %%
theta_0 = math.pi/6 # In radians
v_theta_0 = 0 # Initial radial speed
vr_0 = 0
r_0 = m*g/k  # Initial stretch

theta_0_2 = 0.55 # In radians
v_theta_0_2 = 0 # Initial radial speed
vr_0_2 = 0
r_0_2 = m*g/k  # Initial stretch


state_initial = np.array([r_0, vr_0, theta_0, v_theta_0])
state_initial_2 = np.array([r_0_2, vr_0_2, theta_0_2, v_theta_0_2])
DT = 0.01
interval = 10/DT
T_MAX = 194.8
# k=1
# m=1

t = np.arange(0, T_MAX, DT)
state_pend = np.empty((len(t), 4))
state_pend[0] = state_initial

state_pend2 = np.empty((len(t), 4))
state_pend2[0] = state_initial_2


l0_array = np.repeat(l0, len(t))
l0_array2 = np.repeat(l0, len(t))


def trajectory_rk_numpy(state):
  '''Function to calculate the range of a projectile depending on a given theta and beta'''

  k0 = DT * state[3]
  g0 = DT * state[1]
  l_0 = DT * ang_acc(state[0], state[1], state[2], state[3])
  j0 = DT * radial_acc(state[0], state[2], state[3])


  k1 = DT * (state[3] + l_0/2)
  g1 = DT *(state[1] + j0/2)
  l1 = DT * (ang_acc(state[0] + g0/2, state[1] + j0/2, state[2] + k0/2, state[3] + l_0/2))
  j1 = DT * (radial_acc(state[0] + g0/2, state[2] + k0/2, state[3] + l_0/2))

  k2 = DT * (state[3] + l1/2)
  g2 = DT *(state[1] + j1/2)
  l2 =  DT * (ang_acc(state[0] + g1/2, state[1] + j1/2, state[2] + k1/2, state[3] + l1/2))
  j2 = DT * (radial_acc(state[0] + g1/2, state[2] + k1/2, state[3] + l1/2))

  k3 = DT * (state[3] + l2)
  g3 = DT *(state[1] + j2)
  l3 = DT * (ang_acc(state[0] + g2, state[1] + j2, state[2] + k2, state[3] + l2))
  j3 = DT * (radial_acc(state[0] + g2, state[2] + k2, state[3] + l2))

  r_new = ( state[0] + (g0 + 2*g1 + 2*g2 + g3)/6 )
  theta_new = ( state[2] + (k0 + 2*k1 + 2*k2 +k3)/6 )
  v_theta_new = (state[3] + (l_0 + 2*l1 + 2*l2 + l3)/6)
  v_r_new = (state[1]+ (j0 + 2*j1 + 2*j2 +j3)/6 )

  return [r_new, v_r_new, theta_new, v_theta_new]


for i in range(1, len(t)):
  state_pend[i] = trajectory_rk_numpy(state_pend[i-1])
  state_pend2[i] = trajectory_rk_numpy(state_pend2[i-1])

theta_array = (state_pend[:, 2])
theta_dot_array = (state_pend[:, 3])

theta_array2 = (state_pend2[:, 2])
theta_dot_array2 =(state_pend2[:, 3])


fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(autoscale_on=False, ylim=(-math.pi, math.pi), xlim=(-0.6, 0.6))
ax.set_title('Phase space of spring pendulums')
ax.set_xlabel(r'$\theta$')
ax.set_ylabel(r'$\dot{\theta}$')
#ax.set_aspect('equal')
ax.grid()

#point, = ax.plot([], [], 'o-', lw=2, color='blue')
trace, = ax.plot([], [],  lw=1, ms=2, color='blue')
#point2, = ax.plot([], [], 'o-', lw=2, color='green')
trace2, = ax.plot([], [], lw=1, ms=2, color='green')

time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

def animate(i):
  thisx = [theta_array[i]]
  thisy = [theta_dot_array[i]]

  thisx2 = [theta_array2[i]]
  thisy2 = [theta_dot_array2[i]]

  if i <= 100:
    history_x = theta_array[:i]
    history_y = theta_dot_array2[:i]

    history_x2 = theta_array2[:i]
    history_y2 = theta_dot_array[:i]

  else:
    history_x = theta_array[i - 100:i]
    history_y = theta_dot_array2[i -100:i]

    history_x2 = theta_array2[i-100:i]
    history_y2 = theta_dot_array[i-100:i]


  #point.set_data(thisx, thisy)
  #point2.set_data(thisx2, thisy2)
  trace.set_data(history_x, history_y)
  trace2.set_data(history_x2, history_y2)
  time_text.set_text(time_template % (i*DT))

  return point, point2, trace, trace2, time_text


frames = len(t)/T_MAX
ani_path = '/content/sample_data/animation.mp4'

ani = animation.FuncAnimation(
    fig, animate, len(state_pend), interval = interval, blit=True
)
ani.save(ani_path, writer='ffmpeg', fps= frames)
